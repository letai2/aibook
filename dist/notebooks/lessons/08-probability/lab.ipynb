# %% [markdown]
# <div dir="rtl">
# <h1>از سه بار دیده‌شدن تا احتمال و جریمه</h1>
# <p>درس 10 از 76 · احتمال و لگاریتم به چه درد مدل می‌خورند؟ · <code dir="ltr">08-probability</code></p>
# <p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-03/08-probability.html">📖 بازگشت به همین درس</a></p>
# <p>نسبت شمارش‌ها و منفی لگاریتم احتمال را با رفتار عددی‌شان بشناسید.</p><p>پیش‌نیاز: 03-counts و log در همین درس؛ کتابخانهٔ استاندارد math.</p>
# <p>این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو Cell با برچسب TODO را خودتان کامل کنید. پیام INCOMPLETE یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p>از بالا به پایین اجرا کنید. پس از تغییر هر تابع، Cell آن و سپس Cell آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code>Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl">
# <h2>قبل از اجرا، پیش‌بینی کنید</h2>
# <p>اگر هر دو شمارش [3,1] دو برابر شوند، احتمال‌ها تغییر می‌کنند؟ جریمهٔ احتمال ۰٫۱ چند برابر یا چند واحد با ۰٫۰۱ فرق دارد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl"><p>پیش‌بینی من: …</p></div>

# %%
import math
counts = [3, 1]
print("Observed continuation counts:", counts)

# %% [markdown]
# <div dir="rtl">
# <h2>این بار شما کد بنویسید</h2>
# <p>تابع probabilities(counts) شمارش‌های نامنفی با مجموع مثبت را به فهرست احتمال تبدیل کند. مجموع صفر یا شمارش منفی را با ValueError رد کنید.</p>
# </div>

# %%
def probabilities(counts):
    # TODO: normalize valid counts
    return None

# %%
def test_exercise():
    result = probabilities(counts)
    if result is None:
        return False
    assert result == [0.75, 0.25]
    assert probabilities([6, 2]) == result
    assert probabilities([0, 4]) == [0, 1]
    for invalid in ([0, 0], [-1, 3]):
        try:
            probabilities(invalid)
        except ValueError:
            pass
        else:
            raise AssertionError("Invalid counts must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>فقط یک عامل را تغییر دهید</h2>
# <p>فقط احتمال پاسخ درست را ده برابر کوچک‌تر کنید. اختلاف جریمه‌ها را چاپ کنید؛ این آزمایش نسبت شمارش نیست، رفتار تابع log است.</p>
# </div>

# %%
for p in [0.1, 0.01, 0.001]:
    print(p, -math.log(p))
print("Penalty increment:", -math.log(0.01)+math.log(0.1))

# %% [markdown]
# <div dir="rtl">
# <h2>خرابی را پیدا کنید</h2>
# <p>جمع دو احتمال شرطی، احتمال دو گام پیاپی نیست. تابع sequence_nll باید مجموع منفی لگاریتم احتمال‌های شرطی مثبت را برگرداند؛ احتمالی بیرون بازهٔ (0,1] را رد کنید.</p>
# </div>

# %%
conditional = [0.5, 0.25]
wrong_joint = sum(conditional)
print("Broken joint probability:", wrong_joint, "Actual product:", math.prod(conditional))
assert wrong_joint != math.prod(conditional)

# %% [markdown]
# <div dir="rtl">
# <h2>اصلاح را خودتان بنویسید</h2>
# <p>علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def sequence_nll(probabilities):
    # TODO: return summed negative log probabilities
    return None

# %%
def test_repair():
    result = sequence_nll([0.5, 0.25])
    if result is None:
        return False
    assert math.isclose(result, math.log(8))
    assert sequence_nll([1, 1]) == 0
    try:
        sequence_nll([0])
    except ValueError:
        pass
    else:
        raise AssertionError("Zero probability needs an explicit boundary decision")
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>در Mini-GPT کجا به کار می‌آید؟</h2>
# <p>Loss مدل در mini_gpt/model.py بر احتمال هدف تکیه دارد؛ این آزمایش فقط حساب احتمال را انجام می‌دهد و هنوز آن فایل PyTorch را وارد نمی‌کند.</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>با زبان خودتان توضیح دهید</h2>
# <p>چرا ضرب احتمال‌های شرطی دو گام، به معنی فرض استقلال آن دو Token نیست؟</p>
# </div>
# <div dir="rtl"><p>پیش‌بینی و مشاهدهٔ من: …</p><p>علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl"><p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-03/08-probability.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/08-probability.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
