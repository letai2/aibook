# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">همهٔ درخواست‌ها در برابر همهٔ متن‌ها</h1>
# <p style="text-align:right">درس 9 از 92 · چگونه همهٔ جفت‌ها را یک‌جا مقایسه کنیم؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">07-matmul</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-02/07-matmul.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">جدول مقایسهٔ جفت‌ها را با ضرب ماتریسی خودتان بسازید.</p><p style="text-align:right">پیش‌نیاز: <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">06-dot</code> و مفهوم <bdi dir="ltr">Transpose</bdi> در درس جاری؛ فقط <bdi dir="ltr">Python</bdi>.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۴۵–۸۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">A</code> دو سطر و سه ستون و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">B</code> سه سطر و دو ستون دارد. خروجی چند خانه دارد و خانهٔ سطر صفر، ستون یک از کدام عددها ساخته می‌شود؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
a = [[1, 2, 3], [4, 5, 6]]
b = [[1, 0], [0, 1], [1, 1]]
print("A:", a, "B:", b)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">matmul(a,b)</code> حاصل‌ضرب دو ماتریس مستطیلی غیرخالی را برگرداند. تعداد ستون <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">a</code> باید با تعداد سطر <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">b</code> برابر باشد؛ در غیر این صورت <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> بدهید. اعتبار مستطیلی‌بودن در این تمرین مفروض است.</p>
# </div>

# %%
def matmul(a, b):
    # TODO: each output cell is a row-column dot product
    return None

# %%
def test_exercise():
    result = matmul(a, b)
    if result is None:
        return False
    assert result == [[4, 5], [10, 11]]
    assert matmul([[1, 2], [3, 4]], [[5], [6]]) == [[17], [39]]
    assert matmul([[2]], [[3, 4]]) == [[6, 8]]
    try:
        matmul(a, a)
    except ValueError:
        pass
    else:
        raise AssertionError("Inner dimensions differ")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">A[0][1]</code> را یک واحد زیاد کنید. تغییر خروجی باید به سطر صفر محدود باشد؛ مقدار تغییر هر ستون از سطر یک <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">B</code> می‌آید.</p>
# </div>

# %%
delta = [[0, 1, 0], [0, 0, 0]]
effect = [[sum(delta[i][k]*b[k][j] for k in range(3)) for j in range(2)] for i in range(2)]
print("Change in product:", effect)
assert effect == [[0, 1], [0, 0]]

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">برای مقایسهٔ سطرها باید <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">K</code> را <bdi dir="ltr">Transpose</bdi> کنیم؛ برعکس‌کردن ترتیب سطرها <bdi dir="ltr">Transpose</bdi> نیست. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">transpose</code> را برای ماتریس مستطیلی غیرخالی بنویسید.</p>
# </div>

# %%
keys = [[1, 2], [3, 4], [5, 6]]
wrong = keys[::-1]
print("Reversed rows:", wrong, "shape:", (len(wrong), len(wrong[0])))
assert len(wrong) == 3

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def transpose(matrix):
    # TODO: swap row and column roles
    return None

# %%
def test_repair():
    result = transpose(keys)
    if result is None:
        return False
    assert result == [[1, 3, 5], [2, 4, 6]]
    assert transpose([[1, 2, 3]]) == [[1], [2], [3]]
    assert transpose(result) == keys
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">عمل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">q @ k.transpose(-2,-1)</code> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/attention.py</code> همین جدول جفت‌ها را می‌سازد؛ در آن فایل محورهای <bdi dir="ltr">Batch</bdi> و <bdi dir="ltr">Head</bdi> نیز وجود دارند که بعداً اضافه می‌کنیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا آزمون غیرمربعی برای پیدا‌کردن اشتباه <bdi dir="ltr">Transpose</bdi> مفیدتر است؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-02/07-matmul.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/07-matmul.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
