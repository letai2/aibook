# %% [markdown]
# <div dir="rtl">
# <h1>همهٔ درخواست‌ها در برابر همهٔ متن‌ها</h1>
# <p>درس 9 از 76 · چگونه همهٔ جفت‌ها را یک‌جا مقایسه کنیم؟ · <code dir="ltr">07-matmul</code></p>
# <p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-02/07-matmul.html">📖 بازگشت به همین درس</a></p>
# <p>جدول مقایسهٔ جفت‌ها را با ضرب ماتریسی خودتان بسازید.</p><p>پیش‌نیاز: 06-dot و مفهوم Transpose در درس جاری؛ فقط Python.</p>
# <p>این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو Cell با برچسب TODO را خودتان کامل کنید. پیام INCOMPLETE یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p>از بالا به پایین اجرا کنید. پس از تغییر هر تابع، Cell آن و سپس Cell آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code>Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl">
# <h2>قبل از اجرا، پیش‌بینی کنید</h2>
# <p>A دو سطر و سه ستون و B سه سطر و دو ستون دارد. خروجی چند خانه دارد و خانهٔ سطر صفر، ستون یک از کدام عددها ساخته می‌شود؟</p>
# </div>

# %% [markdown]
# <div dir="rtl"><p>پیش‌بینی من: …</p></div>

# %%
a = [[1, 2, 3], [4, 5, 6]]
b = [[1, 0], [0, 1], [1, 1]]
print("A:", a, "B:", b)

# %% [markdown]
# <div dir="rtl">
# <h2>این بار شما کد بنویسید</h2>
# <p>تابع matmul(a,b) حاصل‌ضرب دو ماتریس مستطیلی غیرخالی را برگرداند. تعداد ستون a باید با تعداد سطر b برابر باشد؛ در غیر این صورت ValueError بدهید. اعتبار مستطیلی‌بودن در این تمرین مفروض است.</p>
# </div>

# %%
def matmul(a, b):
    # TODO: each output cell is a row-column dot product
    return None

# %%
def test_exercise():
    result = matmul(a, b)
    if result is None:
        return False
    assert result == [[4, 5], [10, 11]]
    assert matmul([[1, 2], [3, 4]], [[5], [6]]) == [[17], [39]]
    assert matmul([[2]], [[3, 4]]) == [[6, 8]]
    try:
        matmul(a, a)
    except ValueError:
        pass
    else:
        raise AssertionError("Inner dimensions differ")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>فقط یک عامل را تغییر دهید</h2>
# <p>فقط A[0][1] را یک واحد زیاد کنید. تغییر خروجی باید به سطر صفر محدود باشد؛ مقدار تغییر هر ستون از سطر یک B می‌آید.</p>
# </div>

# %%
delta = [[0, 1, 0], [0, 0, 0]]
effect = [[sum(delta[i][k]*b[k][j] for k in range(3)) for j in range(2)] for i in range(2)]
print("Change in product:", effect)
assert effect == [[0, 1], [0, 0]]

# %% [markdown]
# <div dir="rtl">
# <h2>خرابی را پیدا کنید</h2>
# <p>برای مقایسهٔ سطرها باید K را Transpose کنیم؛ برعکس‌کردن ترتیب سطرها Transpose نیست. تابع Transpose را برای ماتریس مستطیلی غیرخالی بنویسید.</p>
# </div>

# %%
keys = [[1, 2], [3, 4], [5, 6]]
wrong = keys[::-1]
print("Reversed rows:", wrong, "shape:", (len(wrong), len(wrong[0])))
assert len(wrong) == 3

# %% [markdown]
# <div dir="rtl">
# <h2>اصلاح را خودتان بنویسید</h2>
# <p>علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def transpose(matrix):
    # TODO: swap row and column roles
    return None

# %%
def test_repair():
    result = transpose(keys)
    if result is None:
        return False
    assert result == [[1, 3, 5], [2, 4, 6]]
    assert transpose([[1, 2, 3]]) == [[1], [2], [3]]
    assert transpose(result) == keys
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>در Mini-GPT کجا به کار می‌آید؟</h2>
# <p>عمل q @ k.transpose(-2,-1) در mini_gpt/attention.py همین جدول جفت‌ها را می‌سازد؛ در آن فایل محورهای Batch و Head نیز وجود دارند که بعداً اضافه می‌کنیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>با زبان خودتان توضیح دهید</h2>
# <p>چرا آزمون غیرمربعی برای پیدا‌کردن اشتباه Transpose مفیدتر است؟</p>
# </div>
# <div dir="rtl"><p>پیش‌بینی و مشاهدهٔ من: …</p><p>علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl"><p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-02/07-matmul.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/07-matmul.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
