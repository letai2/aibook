# %% [markdown]
# <div dir="rtl">
# <h1>ترکیب دو نمایش بدون تغییر تعداد ویژگی‌ها</h1>
# <p>درس 7 از 76 · از عدد تکی تا جمع وزن‌دار Vectorها · <code dir="ltr">05a-vector-operations</code></p>
# <p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05a-vector-operations.html">📖 بازگشت به همین درس</a></p>
# <p>جمع وزن‌دار Vectorها را از چسباندن list و ضرب داخلی جدا کنید.</p><p>پیش‌نیاز: درس 05-shape؛ حلقه و zip در Python.</p>
# <p>این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو Cell با برچسب TODO را خودتان کامل کنید. پیام INCOMPLETE یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p>از بالا به پایین اجرا کنید. پس از تغییر هر تابع، Cell آن و سپس Cell آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code>Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl">
# <h2>قبل از اجرا، پیش‌بینی کنید</h2>
# <p>در ترکیب ۰٫۲۵ از u و ۰٫۷۵ از v، خروجی چند عدد دارد؟ با ضریب‌های ۱ و صفر چه باید برگردد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl"><p>پیش‌بینی من: …</p></div>

# %%
u, v = [1, 2], [3, -1]
print("Two features per vector:", u, v)

# %% [markdown]
# <div dir="rtl">
# <h2>این بار شما کد بنویسید</h2>
# <p>تابع mix(u,v,a,b) فهرست مؤلفه‌های a*u+b*v را برگرداند. طول نابرابر را با ValueError رد کنید. ضریب‌ها لازم نیست مثبت باشند یا جمعشان یک شود.</p>
# </div>

# %%
def mix(u, v, a, b):
    # TODO: return a weighted vector, not a scalar
    return None

# %%
def test_exercise():
    result = mix(u, v, 0.25, 0.75)
    if result is None:
        return False
    assert result == [2.5, -0.25]
    assert mix(u, v, 1, 0) == u
    assert mix(u, v, 1, -1) == [-2, 3]
    try:
        mix([1], [2, 3], 1, 1)
    except ValueError:
        pass
    else:
        raise AssertionError("Unequal lengths must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>فقط یک عامل را تغییر دهید</h2>
# <p>فقط ضریب a را میان صفر، ۰٫۵ و یک تغییر دهید و b را یک منهای آن بگذارید. ببینید هر مؤلفه میان دو مقدار ورودی می‌ماند؛ این مشاهده برای همین ضریب‌های میانگین وزن‌دار است.</p>
# </div>

# %%
for a in [0, 0.5, 1]:
    print(a, [a*x+(1-a)*y for x, y in zip(u, v)])

# %% [markdown]
# <div dir="rtl">
# <h2>خرابی را پیدا کنید</h2>
# <p>u+v برای list محاسبهٔ موردنظر نیست. تابع add_vectors را بنویسید تا دو Vector هم‌اندازه را مؤلفه‌به‌مؤلفه جمع کند.</p>
# </div>

# %%
wrong = u + v
print("Broken vector addition:", wrong, "length:", len(wrong))
assert len(wrong) == 4

# %% [markdown]
# <div dir="rtl">
# <h2>اصلاح را خودتان بنویسید</h2>
# <p>علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def add_vectors(a, b):
    # TODO: inputs have equal lengths
    return None

# %%
def test_repair():
    result = add_vectors(u, v)
    if result is None:
        return False
    assert result == [4, 1]
    assert add_vectors([0, -2, 4], [3, 2, 1]) == [3, 0, 5]
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>در Mini-GPT کجا به کار می‌آید؟</h2>
# <p>جمع Token و Position در mini_gpt/model.py و جمع وزن‌دار Valueها در mini_gpt/attention.py تعداد ویژگی‌ها را حفظ می‌کنند؛ اینجا فقط حساب لازم را ساختیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>با زبان خودتان توضیح دهید</h2>
# <p>چه زمانی جمع وزن‌دار شما میانگین هم هست، و چه زمانی نیست؟</p>
# </div>
# <div dir="rtl"><p>پیش‌بینی و مشاهدهٔ من: …</p><p>علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl"><p><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05a-vector-operations.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/05a-vector-operations.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
