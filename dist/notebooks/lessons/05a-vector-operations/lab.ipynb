# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">ترکیب دو نمایش بدون تغییر تعداد ویژگی‌ها</h1>
# <p style="text-align:right">درس 7 از 92 · از عدد تکی تا جمع وزن‌دار <bdi dir="ltr">Vector</bdi>ها · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">05a-vector-operations</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05a-vector-operations.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">جمع وزن‌دار <bdi dir="ltr">Vector</bdi>ها را از چسباندن <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">list</code> و ضرب داخلی جدا کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: درس</span> <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">05-shape</code>؛ حلقه و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">zip</code> در <bdi dir="ltr">Python</bdi>.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۴۵–۸۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">در ترکیب ۰٫۲۵ از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">u</code> و ۰٫۷۵ از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">v</code>، خروجی چند عدد دارد؟ با ضریب‌های ۱ و صفر چه باید برگردد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
u, v = [1, 2], [3, -1]
print("Two features per vector:", u, v)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mix(u,v,a,b)</code> فهرست مؤلفه‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">a*u+b*v</code> را برگرداند. طول نابرابر را با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> رد کنید. ضریب‌ها لازم نیست مثبت باشند یا جمعشان یک شود.</p>
# </div>

# %%
def mix(u, v, a, b):
    # TODO: return a weighted vector, not a scalar
    return None

# %%
def test_exercise():
    result = mix(u, v, 0.25, 0.75)
    if result is None:
        return False
    assert result == [2.5, -0.25]
    assert mix(u, v, 1, 0) == u
    assert mix(u, v, 1, -1) == [-2, 3]
    try:
        mix([1], [2, 3], 1, 1)
    except ValueError:
        pass
    else:
        raise AssertionError("Unequal lengths must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط ضریب <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">a</code> را میان صفر، ۰٫۵ و یک تغییر دهید و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">b</code> را یک منهای آن بگذارید. ببینید هر مؤلفه میان دو مقدار ورودی می‌ماند؛ این مشاهده برای همین ضریب‌های میانگین وزن‌دار است.</p>
# </div>

# %%
for a in [0, 0.5, 1]:
    print(a, [a*x+(1-a)*y for x, y in zip(u, v)])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">u+v</code> برای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">list</code> محاسبهٔ موردنظر نیست. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">add_vectors</code> را بنویسید تا دو <bdi dir="ltr">Vector</bdi> هم‌اندازه را مؤلفه‌به‌مؤلفه جمع کند.</p>
# </div>

# %%
wrong = u + v
print("Broken vector addition:", wrong, "length:", len(wrong))
assert len(wrong) == 4

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def add_vectors(a, b):
    # TODO: inputs have equal lengths
    return None

# %%
def test_repair():
    result = add_vectors(u, v)
    if result is None:
        return False
    assert result == [4, 1]
    assert add_vectors([0, -2, 4], [3, 2, 1]) == [3, 0, 5]
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">جمع <bdi dir="ltr">Token</bdi> و <bdi dir="ltr">Position</bdi> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/model.py</code> و جمع وزن‌دار <bdi dir="ltr">Value</bdi>ها در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/attention.py</code> تعداد ویژگی‌ها را حفظ می‌کنند؛ اینجا فقط حساب لازم را ساختیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چه زمانی جمع وزن‌دار شما میانگین هم هست، و چه زمانی نیست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05a-vector-operations.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/05a-vector-operations.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
