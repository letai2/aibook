# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">یک متن، دو نگاشت و یک آزمون رفت‌وبرگشت</h1>
# <p style="text-align:right">درس 3 از 92 · چرا متن را به شناسه تبدیل می‌کنیم؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">02-token</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-02/02-token.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">نگاشت قابل برگشت کاراکتر و شناسه بسازید و خرابی ترتیب <bdi dir="ltr">Vocabulary</bdi> را پیدا کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: درس‌های</span> <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">01-model</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">01-learning</code>؛ دیکشنری و فهرست در <bdi dir="ltr">Python</bdi>.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۳۰–۵۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">اگر فهرست <bdi dir="ltr">Vocabulary</bdi> را پس از <bdi dir="ltr">Encoding</bdi> برعکس کنیم ولی <bdi dir="ltr">ID</bdi>ها را ثابت بگذاریم، طول متن بازگشتی تغییر می‌کند یا محتوا؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
text = "سلام hello!"
vocabulary = sorted(set(text))
to_id = {char: index for index, char in enumerate(vocabulary)}
print("Vocabulary:", list(enumerate(vocabulary)))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">encode(value, mapping)</code> فهرست شناسه‌ها و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">decode(ids, vocabulary)</code> رشته را برگرداند. کاراکترِ ناشناخته باید همان <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">KeyError</code> طبیعی دیکشنری را بدهد؛ فعلاً <bdi dir="ltr">Token</bdi> ناشناخته اضافه نکنید.</p>
# </div>

# %%
def encode(value, mapping):
    # TODO
    return None

def decode(ids, vocabulary):
    # TODO
    return None

# %%
def test_exercise():
    result = encode(text, to_id)
    if result is None:
        return False
    if decode([], vocabulary) is None:
        return False
    assert decode(result, vocabulary) == text
    assert encode("", to_id) == [] and decode([], vocabulary) == ""
    assert encode("abba", {"a": 5, "b": 9}) == [5, 9, 9, 5]
    try:
        encode("ژ", to_id)
    except KeyError:
        pass
    else:
        raise AssertionError("An unknown character must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط فاصله را با نیم‌فاصله جایگزین کنید. با دیدن <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">repr</code> و تعداد کاراکترها توضیح دهید چرا شباهت دیداری، یکسان‌بودن رشته نیست.</p>
# </div>

# %%
for value in ["می روم", "می‌روم"]:
    print(repr(value), len(value), [ord(char) for char in value])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">جدول <bdi dir="ltr">Encoding</bdi> و فهرست <bdi dir="ltr">Decoding</bdi> باید یک ترتیب داشته باشند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mapping_for</code> را طوری بنویسید که ترتیب فهرست ورودی را حفظ کند، نه اینکه مستقلاً آن را مرتب کند.</p>
# </div>

# %%
saved_vocabulary = ["ب", "ا"]
wrong_mapping = {char: i for i, char in enumerate(sorted(saved_vocabulary))}
ids = [wrong_mapping[char] for char in "با"]
wrong_text = "".join(saved_vocabulary[i] for i in ids)
print("Original: با; broken round trip:", wrong_text)
assert wrong_text != "با"

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def mapping_for(vocabulary):
    # TODO: keep the supplied order
    return None

# %%
def test_repair():
    result = mapping_for(["ب", "ا"])
    if result is None:
        return False
    assert result == {"ب": 0, "ا": 1}
    assert mapping_for(["z", "a", "q"]) == {"z": 0, "a": 1, "q": 2}
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">این نسخهٔ کوچک را با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/tokenizer.py</code> اشتباه نگیرید: آن نسخه بعداً <bdi dir="ltr">Unknown token</bdi> و اعتبارسنجی فایل را اضافه می‌کند. اصل حفظ ترتیب در هر دو یکی است.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">کدام آزمون نشان می‌دهد <bdi dir="ltr">ID</bdi>ها به همان کاراکترِ قبلی اشاره می‌کنند، نه فقط به یک کاراکترِ مجاز؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-02/02-token.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/02-token.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
