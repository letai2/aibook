# %% [markdown]
# <div dir="rtl">
# <h1>یک متن، دو نگاشت و یک آزمون رفت‌وبرگشت</h1>
# <p>درس 3 از 76 · چرا متن را به شناسه تبدیل می‌کنیم؟ · <code dir="ltr">02-token</code></p>
# <p><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-02/02-token.html">📖 بازگشت به همین درس</a></p>
# <p>نگاشت قابل برگشت نویسه و شناسه بسازید و خرابی ترتیب Vocabulary را پیدا کنید.</p><p>پیش‌نیاز: درس‌های 01-model و 01-learning؛ دیکشنری و فهرست در Python.</p>
# <p>این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو Cell با برچسب TODO را خودتان کامل کنید. پیام INCOMPLETE یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p>از بالا به پایین اجرا کنید. پس از تغییر هر تابع، Cell آن و سپس Cell آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code>Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl">
# <h2>قبل از اجرا، پیش‌بینی کنید</h2>
# <p>اگر فهرست Vocabulary را پس از Encoding برعکس کنیم ولی IDها را ثابت بگذاریم، طول متن بازگشتی تغییر می‌کند یا محتوا؟</p>
# </div>

# %% [markdown]
# <div dir="rtl"><p>پیش‌بینی من: …</p></div>

# %%
text = "سلام hello!"
vocabulary = sorted(set(text))
to_id = {char: index for index, char in enumerate(vocabulary)}
print("Vocabulary:", list(enumerate(vocabulary)))

# %% [markdown]
# <div dir="rtl">
# <h2>این بار شما کد بنویسید</h2>
# <p>تابع encode(Value, mapping) فهرست شناسه‌ها و decode(ids, Vocabulary) رشته را برگرداند. نویسهٔ ناشناخته باید همان KeyError طبیعی دیکشنری را بدهد؛ فعلاً Token ناشناخته اضافه نکنید.</p>
# </div>

# %%
def encode(value, mapping):
    # TODO
    return None

def decode(ids, vocabulary):
    # TODO
    return None

# %%
def test_exercise():
    result = encode(text, to_id)
    if result is None:
        return False
    if decode([], vocabulary) is None:
        return False
    assert decode(result, vocabulary) == text
    assert encode("", to_id) == [] and decode([], vocabulary) == ""
    assert encode("abba", {"a": 5, "b": 9}) == [5, 9, 9, 5]
    try:
        encode("ژ", to_id)
    except KeyError:
        pass
    else:
        raise AssertionError("An unknown character must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>فقط یک عامل را تغییر دهید</h2>
# <p>فقط فاصله را با نیم‌فاصله جایگزین کنید. با دیدن repr و تعداد نویسه‌ها توضیح دهید چرا شباهت دیداری، یکسان‌بودن رشته نیست.</p>
# </div>

# %%
for value in ["می روم", "می‌روم"]:
    print(repr(value), len(value), [ord(char) for char in value])

# %% [markdown]
# <div dir="rtl">
# <h2>خرابی را پیدا کنید</h2>
# <p>جدول Encoding و فهرست Decoding باید یک ترتیب داشته باشند. تابع mapping_for را طوری بنویسید که ترتیب فهرست ورودی را حفظ کند، نه اینکه مستقلاً آن را مرتب کند.</p>
# </div>

# %%
saved_vocabulary = ["ب", "ا"]
wrong_mapping = {char: i for i, char in enumerate(sorted(saved_vocabulary))}
ids = [wrong_mapping[char] for char in "با"]
wrong_text = "".join(saved_vocabulary[i] for i in ids)
print("Original: با; broken round trip:", wrong_text)
assert wrong_text != "با"

# %% [markdown]
# <div dir="rtl">
# <h2>اصلاح را خودتان بنویسید</h2>
# <p>علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def mapping_for(vocabulary):
    # TODO: keep the supplied order
    return None

# %%
def test_repair():
    result = mapping_for(["ب", "ا"])
    if result is None:
        return False
    assert result == {"ب": 0, "ا": 1}
    assert mapping_for(["z", "a", "q"]) == {"z": 0, "a": 1, "q": 2}
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>در Mini-GPT کجا به کار می‌آید؟</h2>
# <p>این نسخهٔ کوچک را با mini_gpt/tokenizer.py اشتباه نگیرید: آن نسخه بعداً Unknown token و اعتبارسنجی فایل را اضافه می‌کند. اصل حفظ ترتیب در هر دو یکی است.</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>با زبان خودتان توضیح دهید</h2>
# <p>کدام آزمون نشان می‌دهد IDها به همان نویسهٔ قبلی اشاره می‌کنند، نه فقط به یک نویسهٔ مجاز؟</p>
# </div>
# <div dir="rtl"><p>پیش‌بینی و مشاهدهٔ من: …</p><p>علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl"><p><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-02/02-token.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/02-token.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
