# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">همان جدول <bdi dir="ltr">Python</bdi>، این بار در <bdi dir="ltr">Tensor</bdi></h1>
# <p style="text-align:right">درس 17 از 92 · <bdi dir="ltr">PyTorch</bdi> چرا به کارمان می‌آید؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">13-torch</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/13-torch.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">یک <bdi dir="ltr">Batch</bdi> شناسه بسازید و معنای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">shape</code>، <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ndim</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">numel</code> را روی آن بررسی کنید.</p><p style="text-align:right">پیش‌نیاز: <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">05-shape</code> و نصب <bdi dir="ltr">PyTorch</bdi> در همان محیط <bdi dir="ltr">Jupyter</bdi>؛ نیازی به <bdi dir="ltr">NumPy</bdi> نیست.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۰۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">جدول دو متنِ سه‌نشانه‌ای چند محور و چند عنصر دارد؟ آیا عدد سه در شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(2,3)</code> تعداد ویژگی‌هاست؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import torch
torch.set_num_threads(1)
rows = [[1, 2, 3], [4, 5, 6]]
print("PyTorch:", torch.__version__, "Python rows:", rows)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ids_tensor(rows)</code> جدول مستطیلی شناسه‌ها را به <bdi dir="ltr">Tensor</bdi> با نوع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">torch.long</code> و روی <bdi dir="ltr">CPU</bdi> تبدیل کند. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">rows</code> در این تمرین شامل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">int</code> است.</p>
# </div>

# %%
def ids_tensor(rows):
    # TODO: return a CPU integer tensor
    return None

# %%
def test_exercise():
    result = ids_tensor(rows)
    if result is None:
        return False
    assert tuple(result.shape) == (2, 3)
    assert result.ndim == 2 and result.numel() == 6
    assert result.dtype == torch.long and result.device.type == "cpu"
    assert result.tolist() == rows
    assert tuple(ids_tensor([[9, 8]]).shape) == (1, 2)
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط یک متن سه‌نشانه‌ای به <bdi dir="ltr">Batch</bdi> اضافه کنید. سپس فقط یک موقعیت به هر متن اضافه کنید. در هر بار نام محور تغییرکرده را بنویسید.</p>
# </div>

# %%
for value in [rows, rows+[[7, 8, 9]], [[1, 2, 3, 7], [4, 5, 6, 8]]]:
    tensor = torch.tensor(value)
    print(tuple(tensor.shape), tensor.ndim, tensor.numel())

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">دو سطر با طول متفاوت یک جدول مستطیلی نمی‌سازند. خطای عمدی را ببینید و تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">is_rectangular</code> را بنویسید تا پیش از ساخت <bdi dir="ltr">Tensor</bdi> این وضعیت را تشخیص دهد؛ جدول خالی را <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">False</code> در نظر بگیرید.</p>
# </div>

# %%
try:
    torch.tensor([[1, 2], [3]])
except (ValueError, RuntimeError) as error:
    print("Expected ragged-data failure:", error)
else:
    raise AssertionError("Ragged rows should fail")

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def is_rectangular(rows):
    # TODO: require at least one row and one column
    return None

# %%
def test_repair():
    result = is_rectangular([[1, 2], [3, 4]])
    if result is None:
        return False
    assert result is True
    assert is_rectangular([[1, 2], [3]]) is False
    assert is_rectangular([]) is False
    assert is_rectangular([[]]) is False
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">ورودی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">MiniGPT.forward</code> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/model.py</code> شناسه‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,T)</code> است. هنوز محور نمایش <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">C</code> را نساخته‌ایم؛ آن را در آزمایش <bdi dir="ltr">Embedding</bdi> اضافه می‌کنیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">از روی کدام ویژگی <bdi dir="ltr">Tensor</bdi>، تعداد محور را می‌فهمید و از روی کدام، تعداد کل عددها را؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/13-torch.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/13-torch.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
