# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">پاسخ درست روی مرز دو قطعه افتاده است</h1>
# <p style="text-align:right">درس 77 از 92 · سند بلند را کجا ببریم که پاسخ گم نشود؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">69-chunks</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-11/chapter-02/69-chunks.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">اندیس‌های قطعه را خودتان بسازید و ثابت کنید متن اصلی و هویت منبع گم نشده‌اند.</p><p style="text-align:right">پیش‌نیاز: 67-rag و 68-context؛ برش رشته و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">re.finditer</code> در <bdi dir="ltr">Python</bdi>. کلمه‌های این تمرین <bdi dir="ltr">Token</bdi> مدل نیستند.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۰۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">با اندازهٔ چهار کلمه و هم‌پوشانی صفر، عبارت <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">four five</code> در کدام قطعه کامل است؟ هم‌پوشانی یک چه چیزی را عوض می‌کند؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import re
from mini_gpt.retrieval import Document, chunk_document

text = "one two three four five six seven"
print("Word spans:", [(m.group(), m.start(), m.end()) for m in re.finditer(r"\S+", text)])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">chunk_spans(text, size, overlap)</code> جفت‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(start,end)</code> قطعه‌ها را برگرداند. از همان الگوی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">re.finditer</code> در <bdi dir="ltr">Cell</bdi> آماده‌سازی استفاده کنید؛ هر قطعه حداکثر <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">size</code> کلمه داشته باشد و شروع‌ها <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">size-overlap</code> جلو بروند. وقتی قطعه به آخر متن رسید متوقف شوید. شرط <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">0 &lt;= overlap &lt; size</code> را بررسی کنید؛ اندازه‌ها <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">int</code> هستند. متن خالی فهرست خالی بدهد.</p>
# </div>

# %%
def chunk_spans(text, size, overlap):
    # TODO: preserve exact source-string offsets
    return None

# %%
def test_exercise():
    result = chunk_spans(text, 4, 1)
    if result is None:
        return False
    assert [text[a:b] for a,b in result] == ["one two three four", "four five six seven"]
    assert [text[a:b] for a,b in chunk_spans(text,4,0)] == ["one two three four", "five six seven"]
    assert chunk_spans("",4,1) == []
    assert chunk_spans("  abc\td  ",8,0) == [(2,7)]
    try:
        chunk_spans(text,4,4)
    except ValueError:
        pass
    else:
        raise AssertionError("The stride must stay positive")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط هم‌پوشانی را صفر، یک و دو بگذارید. وجود عبارت کامل و مجموع تعداد کلمه‌های قطعه‌ها را مقایسه کنید؛ افزایش شمارِ ذخیره‌شده، افزایش طول سند نیست.</p>
# </div>

# %%
document = Document("guide", text)
for overlap in [0, 1, 2]:
    chunks = chunk_document(document, chunk_words=4, overlap_words=overlap)
    print(overlap, [c.text for c in chunks], "stored words:", sum(len(c.text.split()) for c in chunks),
          "phrase retained:", any("four five" in c.text for c in chunks))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">ذخیرهٔ متن قطعه بدون بررسی منبع می‌تواند ارجاع غلط بسازد. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">verified_source</code> متن قطعه را فقط وقتی برگرداند که شناسهٔ سند موجود و برش <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">start:end</code> دقیقاً برابر متن قطعه باشد؛ وگرنه <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> بدهید.</p>
# </div>

# %%
from mini_gpt.retrieval import Chunk
sources = {"a": "CPU only", "b": "GPU only"}
wrong_chunk = Chunk("bad", "b", "CPU only", 0, 8)
print("Claimed quote:", wrong_chunk.text, "Actual source:", sources[wrong_chunk.document_id])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def verified_source(chunk, sources):
    # TODO: validate source identity and the entire quoted span
    return None

# %%
def test_repair():
    result = verified_source(Chunk("a:0-8","a","CPU only",0,8), sources)
    if result is None:
        return False
    assert result == "CPU only"
    assert verified_source(Chunk("a:0-3","a","CPU",0,3),sources) == "CPU"
    for bad in [wrong_chunk, Chunk("missing","z","CPU",0,3), Chunk("range","a","CPU",-8,3)]:
        try:
            verified_source(bad,sources)
        except ValueError:
            pass
        else:
            raise AssertionError("A wrong or invalid source span must fail")
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">Chunk</code> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/retrieval.py</code> متن، شناسهٔ سند و اندیس‌ها را با هم نگه می‌دارد. این شاهد بعداً وارد <bdi dir="ltr">Context</bdi> و <bdi dir="ltr">Citation</bdi> می‌شود؛ رشتهٔ جداشده بدون هویت کافی نیست.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا دو <bdi dir="ltr">Chunk</bdi> دارای متن مشترک را نباید دو تأیید مستقل برای یک ادعا شمرد؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-11/chapter-02/69-chunks.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/69-chunks.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
