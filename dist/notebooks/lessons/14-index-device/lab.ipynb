# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">یک نمونه را بردارید، <bdi dir="ltr">Batch</bdi> را نگه دارید</h1>
# <p style="text-align:right">درس 18 از 92 · نوع عدد، برش و دستگاه اجرا · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">14-index-device</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/14-index-device.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">انتخاب داده، نوع عدد و دستگاه را جدا بررسی کنید.</p><p style="text-align:right">پیش‌نیاز: <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">13-torch</code>؛ <bdi dir="ltr">Indexing</bdi> و <bdi dir="ltr">Slicing</bdi> درس جاری.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۳۰–۵۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">برای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x</code> با شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(2,3)</code>، <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x[0]</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x[0:1]</code> چه شکل‌هایی دارند؟ تبدیل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">dtype</code> آیا تعداد عنصرها را تغییر می‌دهد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import torch
x = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.long)
print("Input:", x, x.dtype, x.device)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">select_sample(x,index)</code> یک نمونه را با حفظ محور <bdi dir="ltr">Batch</bdi> برگرداند. خروجی باید نوع عدد و دستگاه <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x</code> را نگه دارد؛ اندیس‌های آزمون در محدوده‌اند.</p>
# </div>

# %%
def select_sample(x, index):
    # TODO: preserve the batch axis
    return None

# %%
def test_exercise():
    result = select_sample(x, 0)
    if result is None:
        return False
    assert tuple(result.shape) == (1, 3)
    assert torch.equal(result, torch.tensor([[1, 2, 3]]))
    assert result.dtype == x.dtype and result.device == x.device
    assert select_sample(x, 1).tolist() == [[4, 5, 6]]
    assert tuple(select_sample(x[:1], 0).shape) == (1, 3)
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط نوع عدد را از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">long</code> به <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">float32</code> تغییر دهید. مقدار، شکل و دستگاه را کنار هم چاپ کنید؛ نیازی به <bdi dir="ltr">GPU</bdi> نداریم.</p>
# </div>

# %%
converted = x.float()
for value in [x, converted]:
    print(value.tolist(), tuple(value.shape), value.dtype, value.device)
assert torch.equal(converted.long(), x)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">فراخوانی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">float</code> بدون نگه‌داشتن خروجی، متغیر اصلی را عوض نمی‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">as_float_cpu</code> نتیجهٔ تبدیل را برگرداند و ورودی را دست‌نخورده بگذارد.</p>
# </div>

# %%
original = torch.tensor([1, 2], dtype=torch.long)
original.float()
print("Still integer:", original.dtype)
assert original.dtype == torch.long

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def as_float_cpu(value):
    # TODO: return the conversion result
    return None

# %%
def test_repair():
    result = as_float_cpu(original)
    if result is None:
        return False
    assert result.dtype == torch.float32 and result.device.type == "cpu"
    assert result.tolist() == [1., 2.]
    assert original.dtype == torch.long
    assert as_float_cpu(torch.tensor([[3.]])).shape == (1, 1)
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><bdi dir="ltr">Mini-GPT</bdi> شناسهٔ صحیح و وزن اعشاری را جدا نگه می‌دارد. تبدیل این تمرین برای مشاهده است؛ شناسهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">float</code> را به جدول <bdi dir="ltr">Embedding</bdi> نمی‌دهیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا «عددها همان‌اند» برای اثبات سازگاری دو <bdi dir="ltr">Tensor</bdi> کافی نیست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/14-index-device.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/14-index-device.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
