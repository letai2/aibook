# %% [markdown]
# <div dir="rtl">
# <h1>یک نمونه را بردارید، Batch را نگه دارید</h1>
# <p>درس 18 از 76 · نوع عدد، برش و دستگاه اجرا · <code dir="ltr">14-index-device</code></p>
# <p><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/14-index-device.html">📖 بازگشت به همین درس</a></p>
# <p>انتخاب داده، نوع عدد و دستگاه را جدا بررسی کنید.</p><p>پیش‌نیاز: 13-torch؛ Indexing و Slicing درس جاری.</p>
# <p>این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو Cell با برچسب TODO را خودتان کامل کنید. پیام INCOMPLETE یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p>از بالا به پایین اجرا کنید. پس از تغییر هر تابع، Cell آن و سپس Cell آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code>Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl">
# <h2>قبل از اجرا، پیش‌بینی کنید</h2>
# <p>برای x با شکل (2,3)، x[0] و x[0:1] چه شکل‌هایی دارند؟ تبدیل Dtype آیا تعداد عنصرها را تغییر می‌دهد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl"><p>پیش‌بینی من: …</p></div>

# %%
import torch
x = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.long)
print("Input:", x, x.dtype, x.device)

# %% [markdown]
# <div dir="rtl">
# <h2>این بار شما کد بنویسید</h2>
# <p>تابع select_sample(x,index) یک نمونه را با حفظ محور Batch برگرداند. خروجی باید نوع عدد و دستگاه x را نگه دارد؛ اندیس‌های آزمون در محدوده‌اند.</p>
# </div>

# %%
def select_sample(x, index):
    # TODO: preserve the batch axis
    return None

# %%
def test_exercise():
    result = select_sample(x, 0)
    if result is None:
        return False
    assert tuple(result.shape) == (1, 3)
    assert torch.equal(result, torch.tensor([[1, 2, 3]]))
    assert result.dtype == x.dtype and result.device == x.device
    assert select_sample(x, 1).tolist() == [[4, 5, 6]]
    assert tuple(select_sample(x[:1], 0).shape) == (1, 3)
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>فقط یک عامل را تغییر دهید</h2>
# <p>فقط نوع عدد را از long به float32 تغییر دهید. مقدار، شکل و دستگاه را کنار هم چاپ کنید؛ نیازی به GPU نداریم.</p>
# </div>

# %%
converted = x.float()
for value in [x, converted]:
    print(value.tolist(), tuple(value.shape), value.dtype, value.device)
assert torch.equal(converted.long(), x)

# %% [markdown]
# <div dir="rtl">
# <h2>خرابی را پیدا کنید</h2>
# <p>فراخوانی float بدون نگه‌داشتن خروجی، متغیر اصلی را عوض نمی‌کند. تابع as_float_cpu نتیجهٔ تبدیل را برگرداند و ورودی را دست‌نخورده بگذارد.</p>
# </div>

# %%
original = torch.tensor([1, 2], dtype=torch.long)
original.float()
print("Still integer:", original.dtype)
assert original.dtype == torch.long

# %% [markdown]
# <div dir="rtl">
# <h2>اصلاح را خودتان بنویسید</h2>
# <p>علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def as_float_cpu(value):
    # TODO: return the conversion result
    return None

# %%
def test_repair():
    result = as_float_cpu(original)
    if result is None:
        return False
    assert result.dtype == torch.float32 and result.device.type == "cpu"
    assert result.tolist() == [1., 2.]
    assert original.dtype == torch.long
    assert as_float_cpu(torch.tensor([[3.]])).shape == (1, 1)
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl">
# <h2>در Mini-GPT کجا به کار می‌آید؟</h2>
# <p>Mini-GPT شناسهٔ صحیح و وزن اعشاری را جدا نگه می‌دارد. تبدیل این تمرین برای مشاهده است؛ شناسهٔ float را به جدول Embedding نمی‌دهیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl">
# <h2>با زبان خودتان توضیح دهید</h2>
# <p>چرا «عددها همان‌اند» برای اثبات سازگاری دو Tensor کافی نیست؟</p>
# </div>
# <div dir="rtl"><p>پیش‌بینی و مشاهدهٔ من: …</p><p>علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl"><p><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-01/14-index-device.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/14-index-device.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
