# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">هم‌شکل ولی نه هم‌معنا</h1>
# <p style="text-align:right">درس 20 از 92 · تغییر گروه‌بندی با جابه‌جایی محور فرق دارد · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">16-reshape</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-02/16-reshape.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">گروه‌بندی دوباره را از جابه‌جایی محور با عددهای متمایز جدا کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: درس‌های</span> ۱۳ تا ۱۵؛ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">reshape</code>، <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">transpose</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">squeeze</code> در درس جاری.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۱۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">reshape(3,2)</code> و <bdi dir="ltr">Transpose</bdi> یک جدول ۲×۳ هر دو چه شکلی دارند؟ عدد ۴ در هرکدام کجا قرار می‌گیرد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import torch
small = torch.arange(1, 7).reshape(2, 3)
x = torch.arange(24).reshape(2, 3, 4)
print("Unique source values:", small)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">swap_time_features(x)</code> ورودی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,T,C)</code> را به <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,C,T)</code> ببرد، به‌طوری که عدد هر نمونه و موقعیت واقعاً جابه‌جا شود؛ فقط <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">reshape</code> نکنید.</p>
# </div>

# %%
def swap_time_features(x):
    # TODO: exchange axes 1 and 2
    return None

# %%
def test_exercise():
    result = swap_time_features(x)
    if result is None:
        return False
    assert tuple(result.shape) == (2, 4, 3)
    assert result[1, 2, 0].item() == x[1, 0, 2].item()
    assert torch.equal(swap_time_features(result), x)
    assert not torch.equal(result, x.reshape(2, 4, 3))
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط عملیات را عوض کنید، نه داده را: یک بار <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">reshape</code> و یک بار <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">transpose</code>. جدول عددها را کنار <bdi dir="ltr">Shape</bdi> چاپ کنید.</p>
# </div>

# %%
for name, value in [("regrouped", small.reshape(3, 2)), ("transposed", small.T)]:
    print(name, tuple(value.shape), value.tolist())

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">squeeze</code> بدون <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">dim</code> در <bdi dir="ltr">Batch</bdi> تک‌نمونه‌ای، محور <bdi dir="ltr">Batch</bdi> را هم حذف می‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">remove_middle_unit</code> ورودی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,1,C)</code> را به <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,C)</code> ببرد؛ برای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">B=1</code> نیز <bdi dir="ltr">Batch</bdi> بماند.</p>
# </div>

# %%
single = torch.arange(3).reshape(1, 1, 3)
wrong = single.squeeze()
print("Lost batch axis:", tuple(wrong.shape))
assert tuple(wrong.shape) == (3,)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def remove_middle_unit(x):
    # TODO: remove only axis 1
    return None

# %%
def test_repair():
    result = remove_middle_unit(single)
    if result is None:
        return False
    assert tuple(result.shape) == (1, 3)
    assert torch.equal(result, torch.tensor([[0, 1, 2]]))
    assert tuple(remove_middle_unit(torch.zeros(2, 1, 4)).shape) == (2, 4)
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">تقسیم و اتصال <bdi dir="ltr">Head</bdi>ها در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/attention.py</code> هم <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">reshape</code> دارد و هم <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">transpose</code>. این دو را نمی‌توان صرفاً چون خروجی هم‌شکل است جای هم گذاشت.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا استفاده از عددهای متمایز برای این آزمون از یک <bdi dir="ltr">Tensor</bdi> پر از صفر بهتر است؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-03/chapter-02/16-reshape.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/16-reshape.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
