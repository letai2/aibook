# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">یک منبع اطلاعات، دو درخواست متفاوت</h1>
# <p style="text-align:right">درس 33 از 92 · چه مشکلی با نمایش جداگانهٔ <bdi dir="ltr">Token</bdi>‌ها داریم؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">27-attention-why</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-05/chapter-01/27-attention-why.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">ترکیب وزن‌دار را خودتان بسازید و آن را از میانگین ثابت جدا کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: جمع</span> و ضرب بردار و معنای محور منبع و ویژگی را مرور کنید.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۳۰–۵۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">برای <bdi dir="ltr">Value</bdi>های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">[10,0]</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">[0,20]</code>، درخواست اول وزن <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">[1,0]</code> و درخواست دوم <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">[0.25,0.75]</code> دارد. هر خروجی چند ویژگی دارد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import math
import torch
torch.set_num_threads(1)
torch.manual_seed(17)
values = torch.tensor([[10.,0.],[0.,20.]])
requests = torch.tensor([[1.,0.],[0.25,0.75]])
print('values:',values,'request weights:',requests)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mix_sources(weights, values)</code> را بنویسید. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">weights</code> شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(Q,S)</code>، <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">values</code> شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(S,C)</code> و خروجی شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(Q,C)</code> دارد. هر <bdi dir="ltr">Query</bdi> باید ترکیب خودش را بگیرد؛ اینجا وزن‌ها از قبل داده شده‌اند.</p>
# </div>

# %%
def mix_sources(weights, values):
    # TODO
    return None

# %%
def test_exercise():
    result = mix_sources(requests,values)
    if result is None: return False
    torch.testing.assert_close(result,torch.tensor([[10.,0.],[2.5,15.]]))
    v = torch.tensor([[1.,2.,3.],[4.,5.,6.],[-2.,0.,2.]])
    w = torch.tensor([[0.,0.,1.],[0.5,0.5,0.]])
    torch.testing.assert_close(mix_sources(w,v),torch.stack((v[2],(v[0]+v[1])/2)))
    return True

exercise_complete = test_exercise()
print("PASS" if exercise_complete else "INCOMPLETE: complete the TODO first")

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط سهم منبع اول را از صفر تا یک تغییر دهید و سهم دوم را مکمل آن بگذارید. مسیر خروجی میان دو بردار چگونه است؟</p>
# </div>

# %%
for alpha in (0.,0.25,0.5,0.75,1.):
    print(alpha, alpha*values[0]+(1-alpha)*values[1])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">کد خراب برای همهٔ درخواست‌ها میانگین یکسان می‌دهد. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">request_outputs(weights, values)</code> را طوری اصلاح کنید که واقعاً <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">weights</code> را مصرف کند.</p>
# </div>

# %%
wrong = values.mean(0).expand(requests.shape[0],-1)
print('request ignored:',wrong)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def request_outputs(weights, values):
    # TODO
    return None

# %%
def test_repair():
    result = request_outputs(requests,values)
    if result is None: return False
    torch.testing.assert_close(result,torch.tensor([[10.,0.],[2.5,15.]]))
    torch.testing.assert_close(request_outputs(torch.eye(2),values),values)
    return True

repair_complete = test_repair()
print("PASS" if repair_complete else "INCOMPLETE: complete the TODO first")

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">این جمع همان <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">weights @ v</code> در <bdi dir="ltr">Attention</bdi> پروژه است. هنوز خود <bdi dir="ltr">Attention</bdi> را کامل نساخته‌ایم: در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">MiniGPT</code> وزن‌ها نیز از ورودی، به کمک <bdi dir="ltr">Query</bdi> و <bdi dir="ltr">Key</bdi>، محاسبه می‌شوند.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">کدام قسمت این آزمایش مشکل میانگین ثابت را حل کرد و کدام قسمت هنوز دستی تعیین شده است؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-05/chapter-01/27-attention-why.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/27-attention-why.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
