# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">بردار شمارشی و بردار آموزش‌دیده را با هم اشتباه نگیریم</h1>
# <p style="text-align:right">درس 78 از 92 · امتیاز برداری از کجا معنا پیدا می‌کند؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">70-vectors</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-11/chapter-02/70-vectors.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right"><bdi dir="ltr">Cosine</bdi> و رتبه‌بندی را پیاده کنید و تغییر واقعی یک <bdi dir="ltr">Embedding</bdi> را روی جفت‌های آموزشی ببینید.</p><p style="text-align:right">پیش‌نیاز: 06-dot، 19-network، 25-embedding و 69-chunks؛ <bdi dir="ltr">PyTorch</bdi> از همان محیط پروژه استفاده می‌شود.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۵–۱۱۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">پرسش <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">save</code> با سند <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">keep</code> هیچ واژهٔ مشترکی ندارد. چرا عددهای تصادفی به‌تنهایی این شکست را حل نمی‌کنند؟ پس از آموزش همین جفت، دربارهٔ واژه‌های ندیده چه ادعایی هنوز نمی‌توان کرد؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import math
from collections import Counter
from mini_gpt.retrieval import train_tiny_embeddings, VectorIndex, Document, chunk_document

words, initial, learned, initial_loss, final_loss = train_tiny_embeddings()
print("Provided related pairs:", words[:2], words[2:])
print("Initial vectors:", initial, "Learned vectors:", learned)
print("Loss on the provided pairs, not held-out quality:", initial_loss, final_loss)
assert final_loss < initial_loss

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">rank_vectors(query, rows, k)</code> شمارهٔ حداکثر <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">k</code> سطر را با <bdi dir="ltr">Cosine</bdi> نزولی برگرداند. خودتان <bdi dir="ltr">Dot product</bdi> و <bdi dir="ltr">Norm</bdi> را حساب کنید؛ امتیاز <bdi dir="ltr">Vector</bdi> صفر را صفر بگذارید و امتیازهای صفر یا منفی را برنگردانید. در تساوی، شمارهٔ کوچک‌تر جلوتر باشد. اندازه‌ها سازگار، عددها متناهی و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">k</code> مثبت است.</p>
# </div>

# %%
def rank_vectors(query, rows, k):
    # TODO: calculate cosine scores, then rank row indices
    return None

# %%
def test_exercise():
    result = rank_vectors([1.,0.], [[2.,0.],[1.,1.],[0.,0.],[-1.,0.]], 4)
    if result is None:
        return False
    assert result == [0,1]
    assert rank_vectors([1,0],[[1,0],[4,0]],1) == [0]
    assert rank_vectors([0,0],[[1,0],[0,1]],2) == []
    assert rank_vectors(learned[0],[learned[1],learned[2],learned[3]],1) == [0]
    assert rank_vectors([0,1],[[1,0],[0,1]],2) == [1]
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط تعداد گام آموزش جدول کوچک را از صفر به صد ببرید؛ مقدار آغاز و جفت‌ها ثابت‌اند. امتیاز جفت مرتبط و نامرتبط را جدا ببینید. سپس شکست همان پرسش در <bdi dir="ltr">Index</bdi> شمارشی را ثبت کنید؛ <bdi dir="ltr">Index</bdi> با این آموزش عوض نشده است.</p>
# </div>

# %%
from mini_gpt.retrieval import cosine_similarity
for steps in [0, 100]:
    names, before, after, first, final = train_tiny_embeddings(steps=steps)
    print(steps, "related:", cosine_similarity(after[0],after[1]),
          "unrelated:", cosine_similarity(after[0],after[2]), "loss:",final)
chunks = chunk_document(Document("guide", "keep"),chunk_words=4,overlap_words=0)
index = VectorIndex(chunks)
assert index.search("save") == []
print("Count-vector retrieval for unseen synonym:", index.search("save"))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">دو <bdi dir="ltr">Vector</bdi> تنها وقتی قابل مقایسه‌اند که ستون‌های متناظر معنای یکسان داشته باشند. کد خراب <bdi dir="ltr">Vocabulary</bdi> پرسش را جدا مرتب می‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">encode_shared(text, vocabulary)</code> شمارش واژه‌های جداشده با فاصله را دقیقاً به ترتیب <bdi dir="ltr">Vocabulary</bdi> داده‌شده برگرداند؛ واژه‌های بیرون آن سهمی ندارند.</p>
# </div>

# %%
vocabulary = ["save", "model"]
document_vector = [1, 0]
wrong_query_order = list(reversed(vocabulary))
wrong_query = [int(word == "save") for word in wrong_query_order]
print("Document axes:", vocabulary, "Query axes:", wrong_query_order, "Wrong query:", wrong_query)
assert sum(a*b for a,b in zip(document_vector,wrong_query)) == 0

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def encode_shared(text, vocabulary):
    # TODO: preserve the supplied shared column order
    return None

# %%
def test_repair():
    result = encode_shared("save", vocabulary)
    if result is None:
        return False
    assert result == [1,0]
    assert encode_shared("model save model",vocabulary) == [1,2]
    assert encode_shared("unknown",vocabulary) == [0,0]
    assert encode_shared("model",list(reversed(vocabulary))) == [1,0]
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><bdi dir="ltr">Index</bdi> پروژه شمارشی است؛ جدول چهارواژه‌ای جدا و واقعاً با <bdi dir="ltr">SGD</bdi> آموزش دیده است. بهبود روی همین جفت‌ها شاهد تعمیم نیست و هیچ <bdi dir="ltr">Weight</bdi> از <bdi dir="ltr">Mini-GPT</bdi> با این آزمایش عوض نمی‌شود.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">در هر نمایش، منبع معنا کجاست: قرارداد ستون‌ها، برچسب‌های آموزش، یا صرفاً <bdi dir="ltr">Shape</bdi> بردار؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-11/chapter-02/70-vectors.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/70-vectors.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
