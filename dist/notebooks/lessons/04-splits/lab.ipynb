# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">یک امتیاز خوب با دادهٔ لو‌رفته</h1>
# <p style="text-align:right">درس 5 از 92 · چرا متن ندیده را کنار می‌گذاریم؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">04-splits</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-04/04-splits.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">جداسازی سندها و اثر تکرار را پیش از آموزش شبکه قابل مشاهده کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: درس</span> <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">03-counts</code>؛ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">set</code>، برش فهرست و نسبت دو تعداد.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۱۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">یک برنامه فقط جواب متن‌های دیده‌شده را حفظ کرده است. اگر دو متن ارزیابی را از آموزش کپی کنیم، امتیازش چه می‌شود؟ آیا قابلیت تازه‌ای یاد گرفته است؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
documents = [f"article-{i}" for i in range(10)]
answers = {document: i % 2 for i, document in enumerate(documents)}
print(documents)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">split_documents(items)</code> سه برش ۶، ۲ و ۲تایی برگرداند. این تمرین دقیقاً ده سندِ یکتا دارد. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">overlap(left, right)</code> مجموعهٔ سندهای مشترک را برگرداند.</p>
# </div>

# %%
def split_documents(items):
    # TODO: return train, validation, test
    return None

def overlap(left, right):
    # TODO
    return None

# %%
def test_exercise():
    result = split_documents(documents)
    if result is None:
        return False
    if overlap([], []) is None:
        return False
    train, valid, test = result
    assert [len(train), len(valid), len(test)] == [6, 2, 2]
    assert train + valid + test == documents
    assert overlap(train, valid) == set() and overlap(train, test) == set()
    assert overlap(["a", "b"], ["b", "c"]) == {"b"}
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط دو سند ارزیابی را با دو سند آموزش جایگزین کنید. مدلِ حفظ‌کننده و پاسخ‌ها ثابت‌اند. این مثال عمداً ساده است؛ ادعا نمی‌کند هر نشت داده همیشه همین مقدار به امتیاز اضافه می‌کند.</p>
# </div>

# %%
memory = {name: answers[name] for name in documents[:6]}
for evaluation in [documents[6:8], documents[:2]]:
    score = sum(memory.get(name) == answers[name] for name in evaluation)/len(evaluation)
    print("Evaluation:", evaluation, "Exact-match score:", score)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">دو فهرست، شیءهای متفاوت‌اند ولی ممکن است محتوای مشترک داشته باشند. بررسی <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">is not</code> هیچ نشت محتوایی را رد نمی‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">assert_disjoint</code> باید اشتراک محتوا را رد کند و در حالت سالم <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">True</code> بدهد.</p>
# </div>

# %%
training = ["first", "second"]
validation = ["second", "third"]
print("Broken independence check:", training is not validation)
assert training is not validation and "second" in set(training) & set(validation)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def assert_disjoint(train, validation):
    # TODO: raise ValueError on shared content; otherwise return True
    return None

# %%
def test_repair():
    result = assert_disjoint(["a"], ["b"])
    if result is None:
        return False
    assert result is True
    try:
        assert_disjoint(training, validation)
    except ValueError:
        pass
    else:
        raise AssertionError("Shared document content must be rejected")
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/data.py</code> ابتدا متن را جدا می‌کند و سپس <bdi dir="ltr">Vocabulary</bdi> آموزش را می‌سازد. آن تابع خودش حذف سند تکراری انجام نمی‌دهد؛ بررسی سندها مسئولیتی است که این آزمایش روشن می‌کند.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">تفاوت «دو متغیر جدا» و «دو مجموعهٔ مستقل برای ادعای آزمایش» چیست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-04/04-splits.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/04-splits.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
