# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">تاریخچه در برنامه هست، اما در ورودی نیست</h1>
# <p style="text-align:right">درس 80 از 92 · چرا دستیار پرسش قبلی را از یاد برد؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">72-history</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-12/chapter-01/72-history.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">پیام‌های کامل را انتخاب کنید و اثر حذف یک محدودیت قدیمی را پیش از اجرای مدل ببینید.</p><p style="text-align:right">پیش‌نیاز: 68-context و 71-grounding؛ نقش پیام و تاریخچه در درس 72-history. هیچ آموزش تازه‌ای انجام نمی‌شود.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۰۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">اگر <bdi dir="ltr">CPU</bdi> فقط در پیام نخست آمده باشد، نگه‌داشتن دو پیام آخر چه اطلاعاتی را حذف می‌کند؟ مقدار <bdi dir="ltr">limit</bdi>=0 باید چه برگرداند؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import json
from mini_gpt.memory import Message, format_history

messages = [Message("user","CPU only."), Message("assistant","Open Jupyter."),
            Message("user","Which command now?")]
print("Full history:",format_history(messages))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">recent_messages(messages, limit)</code> یک <bdi dir="ltr">list</bdi> تازه از حداکثر <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">limit</code> پیام آخر، با همان ترتیب، برگرداند. صفر یعنی تاریخچهٔ خالی و مقدار منفی خطای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> است؛ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">limit</code> در این تمرین <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">int</code> است. ورودی را تغییر ندهید و محتوا و نقش هر پیام را حفظ کنید.</p>
# </div>

# %%
def recent_messages(messages, limit):
    # TODO: keep complete messages, including their roles
    return None

# %%
def test_exercise():
    result = recent_messages(messages,2)
    if result is None:
        return False
    assert result == messages[1:]
    assert recent_messages(messages,0) == []
    assert recent_messages(messages,20) == messages
    assert recent_messages(messages,20) is not messages
    assert len(messages) == 3
    assert all(isinstance(message,Message) for message in result)
    try:
        recent_messages(messages,-1)
    except ValueError:
        pass
    else:
        raise AssertionError("Negative history limit")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط تعداد پیام‌های انتخابی را تغییر دهید و با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">format_history</code> واقعی رشتهٔ ورودی را ببینید. دربارهٔ وجود اطلاعات <bdi dir="ltr">CPU</bdi> نتیجه بگیرید، نه کیفیت پاسخ مدلی که هنوز اجرا نکرده‌ایم.</p>
# </div>

# %%
for count in [1,2,3]:
    text = format_history(messages[-count:])
    print(count,"CPU available:","CPU" in text,"characters:",len(text),text)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">چسباندن محتوا بدون نقش، گفتهٔ کاربر و پاسخ احتمالیِ دستیار را یکی می‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">serialize_messages</code> فهرست دیکشنری‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">role</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">content</code> را با <bdi dir="ltr">JSON</bdi> سریال کند. آزمون قالب <bdi dir="ltr">JSON</bdi> را می‌خواند؛ فاصله‌گذاری رشته مهم نیست.</p>
# </div>

# %%
ambiguous = [Message("user","Do not use GPU."),Message("assistant","Use GPU.")]
wrong_text = " ".join(message.content for message in ambiguous)
print("Roles lost:",wrong_text)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def serialize_messages(messages):
    # TODO: retain both role and content for each message
    return None

# %%
def test_repair():
    result = serialize_messages(ambiguous)
    if result is None:
        return False
    assert json.loads(result) == [{"role":"user","content":"Do not use GPU."},
                                  {"role":"assistant","content":"Use GPU."}]
    special = [Message("user",'A "quoted" instruction.\nNext line.')]
    assert json.loads(serialize_messages(special))[0]["content"] == special[0].content
    assert json.loads(serialize_messages([])) == []
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">format_history</code> یک قالب آموزشیِ آشکار می‌سازد. مدل <bdi dir="ltr">Mini-GPT</bdi> صرفاً همین متن را می‌بیند؛ برچسب <bdi dir="ltr">role</bdi> به‌تنهایی نه آموزش <bdi dir="ltr">Chat</bdi> انجام می‌دهد و نه صلاحیت اجرای ابزار می‌دهد.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">حفظ همهٔ پیام‌ها در <bdi dir="ltr">list</bdi> و فرستادن همهٔ پیام‌ها به مدل چه تفاوتی دارند؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-12/chapter-01/72-history.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/72-history.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
