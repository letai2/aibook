# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">انتخاب ضریب با داده، نه با حدس</h1>
# <p style="text-align:right">درس 2 از 92 · یادگیری ماشین دقیقاً چه کاری می‌کند؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">01-learning</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-01/01-learning.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">جست‌وجوی <bdi dir="ltr">Parameter</bdi> را از اجرای مدلِ ثابت جدا کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: درس</span> <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">01-model</code> و محاسبهٔ میانگین مربع خطا با <bdi dir="ltr">Python</bdi>.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۳۰–۶۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">اگر فقط ضریب‌های ۰، ۱ و ۳ را امتحان کنیم، آیا می‌توانیم ضریب ۲ را پیدا کنیم؟ اگر دو گزینه هم‌خطا باشند، کدام را انتخاب می‌کنید؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
data = [(1, 2), (2, 4), (3, 6)]
candidates = [0, 0.5, 1, 1.5, 2, 2.5]
print("Observed examples:", data, "Allowed parameters:", candidates)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">fit(data, candidates)</code> بهترین ضریب را بر اساس میانگین مربع خطا برگرداند. در تساوی، نخستین گزینهٔ فهرست را نگه دارید. تابع نباید <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">data</code> یا <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">candidates</code> را تغییر دهد؛ هر دو ورودی در این تمرین غیرخالی‌اند.</p>
# </div>

# %%
def fit(data, candidates):
    # TODO: return the best candidate; break ties by input order
    return None

# %%
def test_exercise():
    result = fit(data, candidates)
    if result is None:
        return False
    assert result == 2
    assert fit([(1, 2)], [1, 3]) == 1
    assert fit([(1, 2)], [3, 1]) == 3
    assert fit([(1, 3), (2, 6)], candidates) == 2.5
    assert data == [(1, 2), (2, 4), (3, 6)]
    assert candidates == [0, 0.5, 1, 1.5, 2, 2.5]
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط شمارهٔ دو موضوع متن را عوض کنید. آیا پاسخ «این دو موضوع یکسان‌اند؟» تغییر می‌کند؟ فاصلهٔ عددی شناسه‌ها را هم چاپ کنید تا تفاوت نام و مقدار را ببینید.</p>
# </div>

# %%
topics = ["science", "sport", "science"]
for mapping in [{"science": 2, "sport": 7}, {"science": 100, "sport": 1}]:
    ids = [mapping[topic] for topic in topics]
    print(ids, "same topic:", ids[0] == ids[2], "ID distance:", abs(ids[0]-ids[1]))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">برای ساختن هدف از خود متن، جفت‌ها باید همسایه باشند. نسخهٔ خراب هر حرف را با خودش جفت می‌کند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">next_pairs</code> را برای دنبالهٔ دلخواه اصلاح کنید.</p>
# </div>

# %%
text = "baba"
wrong_pairs = list(zip(text, text))
print("Broken input/target pairs:", wrong_pairs)
assert all(current == target for current, target in wrong_pairs)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def next_pairs(sequence):
    # TODO: return adjacent (current, next) pairs
    return None

# %%
def test_repair():
    result = next_pairs("baba")
    if result is None:
        return False
    assert result == [("b", "a"), ("a", "b"), ("b", "a")]
    assert next_pairs([1, 2, 3]) == [(1, 2), (2, 3)]
    assert next_pairs("x") == []
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/stages/v0.py</code> همین جفت‌های مجاور را می‌شمارد. بعداً <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/dataset.py</code> هدف‌های بیشتری را در یک پنجره کنار هم می‌گذارد؛ هدف همچنان از خود متن می‌آید.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">در جست‌وجوی شما چه چیزی از داده انتخاب شد و چه چیزهایی را هنوز خودتان از پیش تعیین کرده بودید؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-01/01-learning.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/01-learning.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
