# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">زمان خواندن روی کارت مقاله</h1>
# <p style="text-align:right">درس 1 از 92 · چه چیزی در یک مدل تغییر می‌کند؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">01-model</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-01/01-model.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">از تعداد بندهای یک مقاله، زمان بسازید و سه ضریب را با همان داده مقایسه کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: فقط</span> تابع، فهرست و حلقهٔ <bdi dir="ltr">Python</bdi>؛ هیچ کتابخانهٔ عددی لازم نیست.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۳۰–۵۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">مقالهٔ تازه چهار بند دارد. ضریب‌های ۱، ۲ و ۳ چه زمان‌هایی می‌دهند؟ کدام زمان مشاهده شده و کدام فقط حدس ماست؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
articles = [(1, 2), (2, 4), (3, 6)]  # paragraphs, measured minutes; synthetic data
print("Paragraphs -> measured minutes:", articles)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">report(data, w)</code> را بنویسید. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">data</code> فهرست جفت‌های تعداد بند و زمان واقعی است. خروجی یک <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">tuple</code> شامل فهرست پیش‌بینی‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">w*x</code> و میانگین مربع اختلاف با زمان واقعی باشد. دادهٔ خالی را با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> رد کنید.</p>
# </div>

# %%
def report(data, w):
    # TODO: return (predictions, mean_squared_error)
    return None

# %%
def test_exercise():
    result = report(articles, 2)
    if result is None:
        return False
    assert result == ([2, 4, 6], 0)
    predictions, loss = report(articles, 1)
    assert predictions == [1, 2, 3] and abs(loss - 14/3) < 1e-12
    assert report([(4, 9)], 2) == ([8], 1)
    try:
        report([], 2)
    except ValueError:
        pass
    else:
        raise AssertionError("Empty data must be rejected")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط زمان ثبت‌شدهٔ مقالهٔ سه‌بندی را از ۶ به ۷ تغییر دهید؛ ضریب را ۲ نگه دارید. پیش‌بینی باید ثابت بماند، اما خطا نه.</p>
# </div>

# %%
changed = [(1, 2), (2, 4), (3, 7)]
fixed_predictions = [2*x for x, _ in changed]
print("Unchanged predictions:", fixed_predictions)
print("Squared errors:", [(p-y)**2 for p, (_, y) in zip(fixed_predictions, changed)])

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">دو خطای با علامت مخالف داریم. چرا میانگین خودِ اختلاف‌ها، کیفیت پیش‌بینی را درست نشان نمی‌دهد؟ نسخهٔ خراب را ببینید و تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">squared_error_mean</code> را اصلاح کنید.</p>
# </div>

# %%
errors = [-2, 2]
wrong_score = sum(errors)/len(errors)
print("Broken score:", wrong_score, "Errors:", errors)
assert wrong_score == 0 and any(error != 0 for error in errors)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def squared_error_mean(errors):
    # TODO: return the mean of squared errors
    return None

# %%
def test_repair():
    result = squared_error_mean([-2, 2])
    if result is None:
        return False
    assert result == 4
    assert squared_error_mean([0, 3]) == 4.5
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/train.py</code> نیز پیش‌بینی و هدف جدا هستند. فعلاً آن فایل را اجرا نمی‌کنیم؛ اینجا همان جدایی را با یک ضریب و زمانِ دقیقه‌ای قابل مشاهده کردیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا تغییر پاسخ واقعی، بدون تغییر ضریب، نباید پیش‌بینی را عوض کند؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-01/chapter-01/01-model.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/01-model.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
