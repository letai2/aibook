# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">گام‌های درست، جواب درست؟</h1>
# <p style="text-align:right">درس 84 از 92 · محاسبهٔ درست برای مسئلهٔ اشتباه · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">76-reasoning</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-13/chapter-02/76-reasoning.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">یک برنامهٔ وابسته بسازید و جواب آن را از خود صورت مسئله وارسی کنید.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: ابزارهای</span> <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">add/multiply</code>، دیکشنری و تفاوت شناسهٔ گام با مقدار آن را از درس بخوانید.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۱۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">هر روز ۲۵ دقیقه مطالعه و ۲۰ دقیقه آزمایش داریم. چرا <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">25+20*3</code> با سه روز اجرای هر دو فعالیت برابر نیست؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
from mini_gpt.reasoning import execute_plan, verify_study_answer
from mini_gpt.tools import ToolError
print('independent task check:',verify_study_answer([25,20],3,135))
print('a locally correct but wrong task answer:',verify_study_answer([25,20],3,85))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">make_study_plan(reading, lab, days)</code> فهرست دو گام بدهد: گام <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">daily</code> جمع دو زمان و گام <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">total</code> ضرب نتیجهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">daily</code> در تعداد روزها. هر گام کلیدهای <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">id/name/arguments</code> دارد؛ <bdi dir="ltr">Argument</bdi> اولِ گام دوم رشتهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">&#x27;daily&#x27;</code> باشد، نه جواب محاسبه‌شدهٔ دستی. عددها نامنفی و در محدودهٔ مثال‌اند.</p>
# </div>

# %%
def make_study_plan(reading, lab, days):
    # TODO
    return None

# %%
def test_exercise():
    result = make_study_plan(25,20,3)
    if result is None: return False
    for reading,lab,days in ((25,20,3),(10,5,4),(0,8,0),(1,0,7)):
        plan = make_study_plan(reading,lab,days)
        assert len(plan) == 2
        assert plan[0]['id'] == 'daily' and plan[1]['id'] == 'total'
        assert plan[1]['arguments']['a'] == 'daily'
        trace = execute_plan(plan)
        assert trace[0].value == reading+lab
        assert verify_study_answer([reading,lab],days,trace[-1].value)
    return True

exercise_complete = test_exercise()
print("PASS" if exercise_complete else "INCOMPLETE: complete the TODO first")

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط سقف گام‌های یک برنامهٔ معلوم را از دو به یک کاهش دهید. برنامهٔ زیر یک محاسبهٔ جداست: زمان سه جلسهٔ ۱۰دقیقه‌ای را می‌گیرد و پنج دقیقه از کل کم می‌کند. چرا برنامهٔ معتبر هم ممکن است از بودجه عبور کند؟</p>
# </div>

# %%
separate_plan = [
    {'id':'sessions','name':'multiply','arguments':{'a':10,'b':3}},
    {'id':'remaining','name':'subtract','arguments':{'a':'sessions','b':5}},
]
for limit in (2,1):
    try: print(limit,execute_plan(separate_plan,max_steps=limit)[-1].value)
    except ToolError as error: print('expected budget stop:',error)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">برنامهٔ خراب تمام ابزارها را درست اجرا کرده، ولی مطالعه را فقط یک روز شمرده است. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">check_answer(reading,lab,days,answer)</code> یک <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">bool</code> بدهد و جواب را مستقل از این برنامه بررسی کند. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">bool</code> را به‌عنوان جواب عددی نپذیرید.</p>
# </div>

# %%
wrong_plan = [
    {'id':'labs','name':'multiply','arguments':{'a':20,'b':3}},
    {'id':'total','name':'add','arguments':{'a':25,'b':'labs'}},
]
wrong_trace = execute_plan(wrong_plan)
print('all tools executed, but answer is:',wrong_trace[-1].value)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def check_answer(reading, lab, days, answer):
    # TODO
    return None

# %%
def test_repair():
    result = check_answer(25,20,3,135)
    if result is None: return False
    assert result is True
    assert check_answer(25,20,3,85) is False
    assert check_answer(10,5,4,60) is True
    assert check_answer(10,5,4,59) is False
    assert check_answer(0,0,3,0) is True
    assert check_answer(1,0,1,True) is False
    return True

repair_complete = test_repair()
print("PASS" if repair_complete else "INCOMPLETE: complete the TODO first")

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">execute_plan</code> گزارش ابزار واقعاً اجراشده را می‌دهد. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">verify_study_answer</code> مسئله را جدا بررسی می‌کند. هیچ‌کدام متنِ توضیح مدل یا <bdi dir="ltr">Activation</bdi>های داخل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">MiniGPT</code> نیست.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">کدام شاهد در این دفتر دربارهٔ صحت عملیات بود و کدام دربارهٔ پاسخ‌دادن به سؤال درست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-13/chapter-02/76-reasoning.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/76-reasoning.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
