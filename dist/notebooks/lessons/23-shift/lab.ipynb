# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">هدف هر موقعیت را با چشم دنبال کنید</h1>
# <p style="text-align:right">درس 27 از 92 · چرا هدف دقیقاً یک خانه جلوتر است؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">23-shift</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-04/chapter-02/23-shift.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">پنجره‌های ورودی/هدف را خودتان بسازید و با <bdi dir="ltr">Dataset</bdi> واقعی تطبیق دهید.</p><p style="text-align:right">پیش‌نیاز: <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">20-loader</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">21-tokenizer</code>؛ برش <bdi dir="ltr">Tensor</bdi>.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۰۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">از پنج <bdi dir="ltr">ID</bdi> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T=3</code> چند نمونه می‌سازیم؟ آخرین هدفِ آخرین نمونه از کدام خانهٔ دنبالهٔ خام می‌آید؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
import torch
from mini_gpt.dataset import NextTokenDataset
ids, T = [1, 2, 3, 4, 5], 3
reference = NextTokenDataset(ids, T)
print("Raw IDs:", ids, "Window length:", T)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">make_windows(ids,T)</code> فهرست جفت‌های <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(x,y)</code> را با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">list</code>های <bdi dir="ltr">Python</bdi> بسازد. <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T</code> باید <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">int</code> مثبت و طول <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ids</code> بیشتر از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T</code> باشد؛ در غیر این صورت <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">ValueError</code> بدهید. هر هدف دقیقاً یک خانه جلوتر است.</p>
# </div>

# %%
def make_windows(ids, T):
    # TODO: include all valid starts and the final target
    return None

# %%
def test_exercise():
    result = make_windows(ids, T)
    if result is None:
        return False
    assert result == [([1, 2, 3], [2, 3, 4]), ([2, 3, 4], [3, 4, 5])]
    assert result == [(x.tolist(), y.tolist()) for x, y in reference]
    assert make_windows([4, 5], 1) == [([4], [5])]
    for invalid_T in (0, 5, True):
        try:
            make_windows(ids, invalid_T)
        except ValueError:
            pass
        else:
            raise AssertionError("Invalid context length must fail")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T</code> را از دو به چهار تغییر دهید. از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">NextTokenDataset</code> واقعی استفاده کنید و تعداد نمونه‌ها و آخرین هدف را کنار هم ببینید.</p>
# </div>

# %%
for length in [2, 3, 4]:
    dataset = NextTokenDataset(ids, length)
    last_x, last_y = dataset[len(dataset)-1]
    print(length, "samples:", len(dataset), "last:", last_x.tolist(), last_y.tolist())

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">برابری طول <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">y</code> ثابت نمی‌کند هدف درست است. نسخهٔ خراب <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">y=x</code> است. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">aligned_target(raw,start,T,target)</code> بررسی کند <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">target</code> دقیقاً برش یک‌خانه‌جلوتر است.</p>
# </div>

# %%
wrong_x = ids[:T]
wrong_y = wrong_x[:]
print("Broken equal-length pair:", wrong_x, wrong_y)
assert len(wrong_x) == len(wrong_y)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def aligned_target(raw, start, T, target):
    # TODO: return a bool; check the whole target including its last item
    return None

# %%
def test_repair():
    result = aligned_target(ids, 0, 3, [2, 3, 4])
    if result is None:
        return False
    assert result is True
    assert aligned_target(ids, 0, 3, wrong_y) is False
    assert aligned_target(ids, 1, 3, [3, 4, 4]) is False
    assert aligned_target(ids, 1, 3, [3, 4, 5]) is True
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">تمام جفت‌ها با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">mini_gpt/dataset.py</code> مقایسه شدند. درست‌بودن <bdi dir="ltr">Shift</bdi> هنوز جلوی دیدن آینده را نمی‌گیرد؛ آن محدودیت را بعداً در <bdi dir="ltr">Attention</bdi> آزمایش می‌کنیم.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">چرا فقط مقایسهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">y[:-1]</code> با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x[1:]</code> برای بررسی آخرین هدف کافی نیست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-04/chapter-02/23-shift.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/23-shift.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
