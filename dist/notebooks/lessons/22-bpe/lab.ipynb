# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">یک ادغام، بدون حذف یا تکرار کاراکترها</h1>
# <p style="text-align:right">درس 26 از 92 · چرا زیرواژه بین کاراکتر و کلمه قرار می‌گیرد؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">22-bpe</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-04/chapter-01/22-bpe.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">ادغام غیرهم‌پوشان و اهمیت ترتیب قواعد <bdi dir="ltr">BPE</bdi> را خودتان پیاده کنید.</p><p style="text-align:right">پیش‌نیاز: <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">21-tokenizer</code> و جفت‌های مجاور؛ این نسخهٔ آموزشی جایگزین <bdi dir="ltr">Tokenizer</bdi> پروژه نیست.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۶۰–۱۰۵ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">با ادغام جفت <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">a,a</code> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">aaaa</code>، چند قطعهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">aa</code> به دست می‌آید؟ آیا می‌توان هر سه جفت هم‌پوشان را نگه داشت؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
from collections import Counter
tokens = list("aaaa")
words = [("کار", 2), ("کارگر", 1), ("گرم", 1)]
print("Initial pieces:", tokens)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">merge(tokens,pair)</code> از چپ به راست حرکت کند؛ دو قطعهٔ متناظر با <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">pair</code> را بچسباند و هر قطعهٔ ورودی را فقط یک بار مصرف کند. ورودی را تغییر ندهید.</p>
# </div>

# %%
def merge(tokens, pair):
    # TODO: merge non-overlapping adjacent pairs
    return None

# %%
def test_exercise():
    result = merge(tokens, ("a", "a"))
    if result is None:
        return False
    assert result == ["aa", "aa"]
    assert merge(list("aaa"), ("a", "a")) == ["aa", "a"]
    assert merge(["کا", "ر", "گ", "ر"], ("کا", "ر")) == ["کار", "گ", "ر"]
    assert merge(["a", "b"], ("x", "y")) == ["a", "b"]
    assert tokens == list("aaaa")
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط فراوانی «گرم» را از یک به ده تغییر دهید. شمارش جفت‌ها را تازه بسازید و ببینید نخستین انتخاب چه تغییری می‌کند؛ قانون تساوی ثابت است.</p>
# </div>

# %%
for frequency in [1, 10]:
    counts = Counter()
    for word, count in [("کار", 2), ("کارگر", 1), ("گرم", frequency)]:
        for pair in zip(word, word[1:]):
            counts[pair] += count
    chosen = min(counts, key=lambda pair: (-counts[pair], pair))
    print("Frequency:", frequency, "Chosen pair:", chosen, "Counts:", counts)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">قواعد ذخیره‌شده باید به ترتیب آموخته‌شده اجرا شوند. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">apply_rules(tokens,rules)</code> تمام قواعد را با ادغام غیرهم‌پوشان اجرا کند؛ مستقل از <bdi dir="ltr">TODO</bdi> اصلی بنویسید تا بتوان هر تمرین را جدا آزمود.</p>
# </div>

# %%
rules = [("a", "b"), ("ab", "c")]
wrong_order = list(reversed(rules))
pieces = list("abc")
for left, right in wrong_order:
    index = 0
    while index+1 < len(pieces):
        if pieces[index:index+2] == [left, right]:
            pieces[index:index+2] = [left+right]
        index += 1
print("Rules in reverse order:", pieces)
assert pieces == ["ab", "c"]

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def apply_rules(tokens, rules):
    # TODO: apply the supplied rules in their given order
    return None

# %%
def test_repair():
    result = apply_rules(list("abc"), rules)
    if result is None:
        return False
    assert result == ["abc"]
    assert apply_rules(list("aaaa"), [("a", "a")]) == ["aa", "aa"]
    assert apply_rules(list("abc"), []) == ["a", "b", "c"]
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right"><bdi dir="ltr">Mini-GPT</bdi> فعلی عمداً از <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">CharacterTokenizer</code> استفاده می‌کند. <bdi dir="ltr">BPE</bdi> این دفتر یک آزمایش مستقل دربارهٔ طول دنباله است، نه <bdi dir="ltr">API</bdi> پنهان یا پیاده‌سازی کامل <bdi dir="ltr">BPE</bdi> در پروژه.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">برای بازسازی <bdi dir="ltr">Encoding</bdi>، چرا داشتن فهرست قطعه‌های نهایی به‌تنهایی کافی نیست؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-04/chapter-01/22-bpe.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/22-bpe.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
