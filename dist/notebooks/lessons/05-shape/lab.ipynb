# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h1 style="text-align:right">نشانی هر عدد در یک <bdi dir="ltr">Batch</bdi> متن</h1>
# <p style="text-align:right">درس 6 از 92 · یک بردار و یک محور دقیقاً چیست؟ · <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">05-shape</code></p>
# <p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05-shape.html">📖 بازگشت به همین درس</a></p>
# <p style="text-align:right">سه محور را با مقدار قابل ردیابی بسازید؛ نه فقط با یک <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">tuple</code> از اندازه‌ها.</p><p style="text-align:right"><span class="phrase-lead" style="white-space:nowrap">پیش‌نیاز: فهرست</span> تو‌در‌تو و حلقهٔ <bdi dir="ltr">Python</bdi>؛ هنوز <bdi dir="ltr">PyTorch</bdi> لازم نیست.</p>
# <p style="text-align:right">زمان یادگیری درس همراه با همین دفتر: حدود ۴۵–۸۰ دقیقه. زمان دفتر دوباره به زمان درس اضافه نمی‌شود؛ نصب و تمرین اختیاری جداست.</p>
# <p style="text-align:right">این دفتر نیمهٔ عملی درس است. مثال‌ها آمادهٔ اجرا هستند؛ دو <bdi dir="ltr">Cell</bdi> با برچسب <bdi dir="ltr">TODO</bdi> را خودتان کامل کنید. پیام <bdi dir="ltr">INCOMPLETE</bdi> یعنی هنوز چیزی ننوشته‌اید، نه اینکه پاسخ درست است. جواب مرجع در این دفتر پنهان نشده است.</p>
# <p style="text-align:right">از بالا به پایین اجرا کنید. پس از تغییر هر تابع، <bdi dir="ltr">Cell</bdi> آن و سپس <bdi dir="ltr">Cell</bdi> آزمون را دوباره اجرا کنید. برای بررسی نهایی، از منوی <code style="direction:ltr;text-align:left;unicode-bidi:isolate">Kernel → Restart Kernel and Run All Cells</code> استفاده کنید.</p>
# </div>

# %%
from pathlib import Path
import os
import sys

project_root = next((p for p in (Path.cwd(), *Path.cwd().parents)
                     if (p / "mini_gpt").is_dir() and (p / "book_src").is_dir()), None)
if project_root is None:
    raise RuntimeError("Extract the complete learning project; open this notebook inside it.")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
print("Python:", sys.executable)
print("Project:", project_root)

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">قبل از اجرا، پیش‌بینی کنید</h2>
# <p style="text-align:right">در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">B=2</code>، <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T=3</code> و <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">C=4</code>، مقدار <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">100*b+10*t+c</code> در <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">x[1][2][0]</code> چیست؟ اگر فقط <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">T</code> دو برابر شود، کدام شمار تغییر می‌کند؟</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی من: …</p></div>

# %%
B, T, C = 2, 3, 4
print("Axes: sample, token position, feature", (B, T, C))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">این بار شما کد بنویسید</h2>
# <p style="text-align:right">تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">make_grid(B,T,C)</code> فهرست سه‌محوری بسازد و خانهٔ <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">b,t,c</code> را برابر <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">100*b+10*t+c</code> بگذارد. اندازه‌ها در آزمون مثبت‌اند. فهرست‌های درونی باید مستقل باشند.</p>
# </div>

# %%
def make_grid(B, T, C):
    # TODO: construct independent nested lists
    return None

# %%
def test_exercise():
    result = make_grid(2, 3, 4)
    if result is None:
        return False
    assert len(result) == 2 and all(len(sample) == 3 for sample in result)
    assert all(len(row) == 4 for sample in result for row in sample)
    assert result[1][2][0] == 120 and result[0][1][3] == 13
    assert make_grid(1, 2, 2) == [[[0, 1], [10, 11]]]
    result[0][0][0] = -1
    assert result[1][0][0] == 100
    return True

exercise_complete = test_exercise()
print('PASS' if exercise_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">فقط یک عامل را تغییر دهید</h2>
# <p style="text-align:right">فقط تعداد موقعیت‌ها را از ۳ به ۶ تغییر دهید؛ تعداد نمونه و ویژگی ثابت باشند. تعداد عددها را قبل از دیدن جدول حساب کنید.</p>
# </div>

# %%
for positions in [3, 6]:
    lengths = [[C for _ in range(positions)] for _ in range(B)]
    print("Shape:", (B, positions, C), "Elements:", sum(sum(sample) for sample in lengths))

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">خرابی را پیدا کنید</h2>
# <p style="text-align:right">ساخت جدول با ضرب <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">list</code>، یک فهرست مشترک را چند بار ارجاع می‌دهد. تابع <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">zeros_grid</code> باید جدول سه‌محوری صفر بسازد که تغییر یک خانه، خانهٔ دیگری را تغییر ندهد.</p>
# </div>

# %%
aliased = [[[0]*C]*T]*B
aliased[0][0][0] = 99
print("Unintended second-sample change:", aliased[1][0][0])
assert aliased[1][0][0] == 99

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">اصلاح را خودتان بنویسید</h2>
# <p style="text-align:right">علت را توضیح دهید، سپس تابع زیر را کامل کنید. خطای عمدی بالا یک نمونهٔ آموزشی است؛ آزمون پایین باید اصلاح شما را بسنجد.</p>
# </div>

# %%
def zeros_grid(B, T, C):
    # TODO: make each inner list independently
    return None

# %%
def test_repair():
    result = zeros_grid(2, 3, 4)
    if result is None:
        return False
    assert result == [[[0]*4 for _ in range(3)] for _ in range(2)]
    result[0][0][0] = 99
    assert result[0][1][0] == 0 and result[1][0][0] == 0
    return True

repair_complete = test_repair()
print('PASS' if repair_complete else 'INCOMPLETE: implement the TODO and rerun')

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> کجا به کار می‌آید؟</h2>
# <p style="text-align:right">در <bdi dir="ltr">Mini-GPT</bdi> شناسه‌ها شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,T)</code> و نمایش هر شناسه شکل <code dir="ltr" style="direction:ltr;text-align:left;unicode-bidi:isolate">(B,T,C)</code> دارد. مقدارهای این آزمایش فقط برچسب نشانی‌اند؛ ویژگی زبانیِ یادگرفته‌شده نیستند.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align:right">
# <h2 style="text-align:right">با زبان خودتان توضیح دهید</h2>
# <p style="text-align:right">اگر تعداد عنصرها درست باشد، چه آزمونی هنوز برای اطمینان از معنای محور لازم است؟</p>
# </div>
# <div dir="rtl" style="text-align:right"><p style="text-align:right">پیش‌بینی و مشاهدهٔ من: …</p><p style="text-align:right">علت خرابی و اصلاح من: …</p></div>

# %% [markdown]
# <div dir="rtl" style="text-align:right"><p style="text-align:right"><a target="_self" href="http://127.0.0.1:8000/part-02/chapter-01/05-shape.html">بازگشت به درس و ادامهٔ مسیر</a> · <a target="_self" href="http://127.0.0.1:8000/answers/05-shape.html#lab-solution">فقط پس از تلاش: راه‌حل مرجع آزمایشگاه</a></p></div>
